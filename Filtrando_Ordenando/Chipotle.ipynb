# %%
#1
import pandas as pd

# %%
#2 e 3
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t', index_col = 'order_id')
chipo.head(5)
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#4 Não consigo visualizar o 4, então tive que seguir o gabarito
formatando = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(formatando)
chipo.item_price.head(5)
# Out:
# order_id
# 1     2.39
# 1     3.39
# 1     3.39
# 1     2.39
# 2    16.98
# Name: item_price, dtype: float64

# %%
#Filtrando pedidos iguais
chipo_filtered = chipo.drop_duplicates(['item_name','quantity'])
chipo_one_prod = chipo_filtro[chipo_filtered.quantity == 1]
chipo_one_prod[chipo_one_prod['item_price'] > 10].item_name.nunique()
# Out:
# 12

# %%
#5 Não entendi muito bem o exercicio, portanto fiz da minha forma. Mas bateu com o gabarito não com a resolução
chipoSemRep = chipo.drop_duplicates(['item_name', 'quantity'])
selecao = list(chipoSemRep.quantity == 1)
chipo_coisas = chipoSemRep[selecao].sort_values('item_price',ascending=False)
chipo_coisas[['item_name','item_price']]
# Out:
#                                       item_name  item_price
# order_id
# 250                            Steak Salad Bowl       11.89
# 501                         Barbacoa Salad Bowl       11.89
# 468                         Carnitas Salad Bowl       11.89
# 4                                 Steak Burrito       11.75
# 75                        Barbacoa Crispy Tacos       11.75
# 19                                Barbacoa Bowl       11.75
# 304                           Veggie Soft Tacos       11.25
# 83                            Veggie Salad Bowl       11.25
# 28                                  Veggie Bowl       11.25
# 26                               Veggie Burrito       11.25
# 109                               Chicken Salad       10.98
# 3                                  Chicken Bowl       10.98
# 4                              Steak Soft Tacos        9.25
# 230                       Carnitas Crispy Tacos        9.25
# ...

# %%
#6
chipo.sort_values('item_name')
# Out:
#           quantity          item_name  \
# order_id
# 1360             2  6 Pack Soft Drink
# 148              1  6 Pack Soft Drink
# 749              1  6 Pack Soft Drink
# 754              1  6 Pack Soft Drink
# 1076             1  6 Pack Soft Drink
# 1373             1  6 Pack Soft Drink
# 230              1  6 Pack Soft Drink
# 774              1  6 Pack Soft Drink
# 776              1  6 Pack Soft Drink
# 784              1  6 Pack Soft Drink
# 1537             1  6 Pack Soft Drink
# 129              1  6 Pack Soft Drink
# 798              1  6 Pack Soft Drink
# 481              1  6 Pack Soft Drink
# 1554             1  6 Pack Soft Drink
# 465              1  6 Pack Soft Drink
# 1558             1  6 Pack Soft Drink
# 849              1  6 Pack Soft Drink
# 1196             1  6 Pack Soft Drink
# 1803             1  6 Pack Soft Drink
# 1664             1  6 Pack Soft Drink
# 1666             1  6 Pack Soft Drink
# 1800             1  6 Pack Soft Drink
# ...

# %%
#7
chipo_ordenado = chipo.sort_values('item_price', ascending = False)
chipo_ordenado.head(1)
# Out:
#           quantity                     item_name choice_description  \
# order_id
# 1443            15  Chips and Fresh Tomato Salsa                NaN
#
#           item_price
# order_id
# 1443           44.25

# %%
#8
selecao = list(chipo['item_name'] == 'Veggie Salad Bowl')
chipo[selecao].shape[0]
# Out:
# 18
